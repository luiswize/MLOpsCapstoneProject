# %%
import pandas as pd
import numpy as np
from sentence_transformers.losses import CosineSimilarityLoss
from setfit import SetFitModel, SetFitTrainer, sample_dataset
from sklearn.model_selection import train_test_split

# %%
! python -m pip install setfit -q

# %%
! python -m pip install git+https://github.com/huggingface/setfit.git --use-pep517 -q

# %%
# !python -m pip install git+https://github.com/huggingface/setfit.git

# %%
df = pd.read_csv('../data/labeled_data/labeled_data_v0.csv')

# %%
df.head()
# Out:
#                                       Message-ID                 Date  \
# 0   <8307461.1075860887277.JavaMail.evans@thyme>  2004-03-02 18:14:47
# 1  <31088330.1075860887438.JavaMail.evans@thyme>  2004-03-02 18:14:47
# 2   <8829953.1075860887541.JavaMail.evans@thyme>  2004-03-02 18:14:47
# 3  <25503194.1075860887462.JavaMail.evans@thyme>  2004-03-02 18:14:47
# 4   <3520246.1075860887301.JavaMail.evans@thyme>  2004-03-02 18:14:47
#
#                                 From                       To  \
# 0  ["hotwecash@lists.adversend.com"]  ["m..presto@enron.com"]
# 1  ["hotwecash@lists.adversend.com"]  ["m..presto@enron.com"]
# 2  ["hotwecash@lists.adversend.com"]  ["m..presto@enron.com"]
# 3  ["hotwecash@lists.adversend.com"]  ["m..presto@enron.com"]
# 4  ["hotwecash@lists.adversend.com"]  ["m..presto@enron.com"]
#
#                                     Subject   Cc  Mime-Version  \
# 0            Free Grants For Those In Need!  NaN           1.0
# ...

# %%
train_df, test_df = train_test_split(df, test_size=0.2)

# %%
# # Load a SetFit model from Hub
model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-mpnet-base-v2", cache_dir=)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/p8/hcc3hbg92yvd4fclbgllz3380000gn/T/ipykernel_6875/604231100.py in <module>
#       1 # # Load a SetFit model from Hub
# ----> 2 model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-mpnet-base-v2")
#
# ~/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     122             )
#     123
# --> 124         return fn(*args, **kwargs)
#     125
#     126     return _inner_fn  # type: ignore
#
# ~/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages/huggingface_hub/hub_mixin.py in from_pretrained(cls, pretrained_model_name_or_path, force_download, resume_download, proxies, token, cache_dir, local_files_only, **model_kwargs)
# ...

# %%
# from datasets import load_dataset
# from sentence_transformers.losses import CosineSimilarityLoss


# # Load a dataset from the Hugging Face Hub
# dataset = load_dataset("sst2")

# # Simulate the few-shot regime by sampling 8 examples per class
# train_dataset = sample_dataset(dataset["train"], label_column="label", num_samples=8)
# eval_dataset = dataset["validation"]

# # Load a SetFit model from Hub
# model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-mpnet-base-v2")

# # Create trainer
# trainer = SetFitTrainer(
#     model=model,
#     train_dataset=train_dataset,
#     eval_dataset=eval_dataset,
#     loss_class=CosineSimilarityLoss,
#     metric="accuracy",
#     batch_size=16,
#     num_iterations=20, # The number of text pairs to generate for contrastive learning
#     num_epochs=1, # The number of epochs to use for constrastive learning
#     column_mapping={"sentence": "text", "label": "label"} # Map dataset columns to text/label expected by trainer
# )

# # Train and evaluate
# trainer.train()
# metrics = trainer.evaluate()

# # Push model to the Hub
# trainer.push_to_hub("my-awesome-setfit-model")

# # Download from Hub and run inference
# model = SetFitModel.from_pretrained("lewtun/my-awesome-setfit-model")
# # Run inference
# preds = model(["i loved the spiderman movie!", "pineapple on pizza is the worst 🤮"])
