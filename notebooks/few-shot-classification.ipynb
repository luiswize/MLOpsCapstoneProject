# %%
from typing import List, Union
from tqdm import tqdm
import string
import datetime
from dateutil import parser
import multiprocessing as mp

import pandas as pd
import numpy as np
import spacy
import nltk
from nltk.corpus import stopwords
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Data Cleaning Utilities

# %%
def change_date_type(dates: Union[pd.DataFrame, pd.Series]) -> List:
    """
    Formats string column into datetime object
    """
    column = []
    
    for date in dates:
        column.append(parser.parse(date).strftime("%d-%m-%Y %H:%M:%S"))
    
    series = pd.Series(column)
    return pd.to_datetime(series)


def str_to_list(row):
    """convert a string List into a List"""
    row = str(row).strip("[]").replace("'","")
    return row


def parsed_email_processing(df: pd.DataFrame) -> pd.DataFrame:
    """
    Basic email formatting and cleaning
    """
    
    df['Date'] = change_date_type(df['Date'])
    
    df['body'] = df['body'].str.replace('\n','').str.replace('\t','')
    
    df['To'] = df['To'].astype('str')\
        .str.replace('b','')\
        .apply(str_to_list)
        
    df['From'] = df['From'].astype('str')\
        .str.replace('b','')\
        .apply(str_to_list)
    
    return df

# %% [markdown]
# ### Text Normalization Utilities

# %%
def spacy_normalization_process(text):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    
    lemma_list = []
    for token in doc:
        lemma_list.append(token.lemma_)
    print("Tokenize+Lemmatize:")
    print(lemma_list)
    
    filtered_sentence =[] 
    for word in lemma_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_sentence.append(word) 
    
    #Remove punctuation
    punctuations="?:!.,;"
    for word in filtered_sentence:
        if word in punctuations:
            filtered_sentence.remove(word)
    
    return filtered_sentence

# %%
nlp = spacy.load("en_core_web_sm")
stops = stopwords.words("english")

def _normalize(comment, lowercase, remove_stopwords):
    if lowercase:
        comment = comment.lower()
    comment = nlp(comment)
    lemmatized = list()
    for word in comment:
        lemma = word.lemma_.strip()
        if lemma:
            if not remove_stopwords or (remove_stopwords and lemma not in stops):
                lemmatized.append(lemma)
    return " ".join(lemmatized)


# result = test['body'].apply(_normalize, lowercase=True, remove_stopwords=True).to_frame()

# %%
nlp = spacy.load("en_core_web_sm")

class TextPreprocessor(BaseEstimator, TransformerMixin):
    def __init__(self,
                 nlp = nlp,
                 n_jobs=1):
        """
        Text preprocessing transformer includes steps:
            1. Punctuation removal
            2. Stop words removal
            3. Lemmatization

        nlp  - spacy model
        n_jobs - parallel jobs to run
        """
        self.nlp = nlp
        self.n_jobs = n_jobs

    def fit(self, X, y=None):
        return self
    

    def transform(self, X, *_):
        X_copy = X.copy()

        partitions = 1
        cores = mp.cpu_count()
        if self.n_jobs <= -1:
            partitions = cores
        elif self.n_jobs <= 0:
            return X_copy.apply(self._preprocess_text)
        else:
            partitions = min(self.n_jobs, cores)

        data_split = np.array_split(X_copy, partitions)
        pool = mp.Pool(cores)
        data = pd.concat(pool.map(self._preprocess_part, data_split))
        pool.close()
        pool.join()

        return data
    
    
    def _remove_punct(self, doc):
        return (t for t in doc if t.text not in string.punctuation)
    

    def _remove_stop_words(self, doc):
        return (t for t in doc if not t.is_stop)
    

    def _lemmatize(self, doc):
        return ' '.join(t.lemma_ for t in doc)
    

    def _preprocess_text(self, text):
        doc = self.nlp(text)
        removed_punct = self._remove_punct(doc)
        removed_stop_words = self._remove_stop_words(removed_punct)
        return self._lemmatize(removed_stop_words)
    
    
    def _preprocess_part(self, part):
        return part.apply(self._preprocess_text)

# %% [markdown]
# ### Text features

# %%
not_spam_df = pd.read_parquet('../data/labeled_data/nonspam.parquet.gzip')
spam_df = pd.read_parquet('../data/labeled_data/spam.parquet.gzip')

# %%
complete_df = pd.concat([spam_df, not_spam_df]).reset_index(drop=True)

# %%
complete_df = parsed_email_processing(complete_df)

# %%
nlp = spacy.load("en_core_web_sm")
Normalizer = TextPreprocessor(nlp, -1)
complete_df['body_transformed'] = Normalizer.transform(complete_df['body'])

# %%
complete_df
# Out:
#                                          Message-ID                Date  \
# 0      <8307461.1075860887277.JavaMail.evans@thyme> 2004-03-02 18:14:47
# 1     <31088330.1075860887438.JavaMail.evans@thyme> 2004-03-02 18:14:47
# 2      <8829953.1075860887541.JavaMail.evans@thyme> 2004-03-02 18:14:47
# 3     <25503194.1075860887462.JavaMail.evans@thyme> 2004-03-02 18:14:47
# 4      <3520246.1075860887301.JavaMail.evans@thyme> 2004-03-02 18:14:47
# ...                                             ...                 ...
# 1481  <24512566.1075858195244.JavaMail.evans@thyme> 2000-05-15 00:56:00
# 1482  <14280509.1075852831215.JavaMail.evans@thyme> 2001-10-29 17:51:00
# 1483   <3806755.1075861627055.JavaMail.evans@thyme> 2001-09-11 05:55:00
# 1484  <22003901.1075862106346.JavaMail.evans@thyme> 2001-11-19 12:32:00
# 1485  <31521917.1075860074692.JavaMail.evans@thyme> 2000-06-16 09:52:00
#
#                                    From                            To  \
# 0     ["hotwecash@lists.adversend.com"]       ["m..presto@enron.com"]
# 1     ["hotwecash@lists.adversend.com"]       ["m..presto@enron.com"]
# 2     ["hotwecash@lists.adversend.com"]       ["m..presto@enron.com"]
# 3     ["hotwecash@lists.adversend.com"]       ["m..presto@enron.com"]
# 4     ["hotwecash@lists.adversend.com"]       ["m..presto@enron.com"]
# ...                                 ...                           ...
# 1481            "mike.carson@enron.com"          "mjmoreland@aep.com"
# 1482       "arsystem@mailman.enron.com"         "m..presto@enron.com"
# 1483             "d..steffes@enron.com"   "richard.shapiro@enron.com"
# 1484              "e..carter@enron.com"  "monika.causholli@enron.com"
# 1485            "mark.taylor@enron.com"  "janette.elertson@enron.com"
#
#                                                 Subject  \
# 0                        Free Grants For Those In Need!
# 1                      Your Opinion Counts...Win $1000!
# 2                               LOSE POUNDS GUARANTEED!
# 3                         Someone is searching for YOU!
# 4              Take a Survey, Win a FREE New Computer!!
# ...                                                 ...
# 1481                                       Re: Hey, DOG
# 1482  Your Approval is Overdue: Access Request for t...
# 1483                                           FW: Visa
# 1484                                          RE: Class
# 1485                           Letter to Chairman Ewing
#
#                                      Cc Mime-Version  \
# 0                                  None          1.0
# 1                                  None          1.0
# 2                                  None          1.0
# 3                                  None          1.0
# 4                                  None          1.0
# ...                                 ...          ...
# 1481                               None            1
# 1482                               None            1
# 1483                               None            1
# 1484                               None            1
# 1485  b'["cynthia.sandherr@enron.com"]'            1
#
#                       Content-Type Content-Transfer-Encoding  \
# 0     text/plain; charset=us-ascii                      7bit
# 1     text/plain; charset=us-ascii                      7bit
# 2     text/plain; charset=us-ascii                      7bit
# 3     text/plain; charset=us-ascii                      7bit
# 4     text/plain; charset=us-ascii                      7bit
# ...                            ...                       ...
# 1481  text/plain; charset=us-ascii                      7bit
# 1482  text/plain; charset=us-ascii                      7bit
# 1483  text/plain; charset=us-ascii                      7bit
# 1484  text/plain; charset=us-ascii                      7bit
# 1485  text/plain; charset=us-ascii                      7bit
#
#                                     Bcc  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ...                                 ...
# 1481                               None
# 1482                               None
# 1483                               None
# 1484                               None
# 1485  b'["cynthia.sandherr@enron.com"]'
#
#                                                  X-From  \
# 0     HotWebCash Newsletter <hotwebcash@lists.advers...
# 1     HotWebCash Newsletter <hotwebcash@lists.advers...
# 2     HotWebCash Newsletter <hotwebcash@lists.advers...
# 3     HotWebCash Newsletter <hotwebcash@lists.advers...
# 4     HotWebCash Newsletter <hotwebcash@lists.advers...
# ...                                                 ...
# 1481                                        Mike Carson
# 1482        ARSystem <ARSystem@mailman.enron.com>@ENRON
# 1483  Steffes, James D. </O=ENRON/OU=NA/CN=RECIPIENT...
# 1484  Carter, Karen E. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 1485                                        Mark Taylor
#
#                                                    X-To              X-cc  \
# 0     Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 1     Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 2     Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 3     Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4     Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# ...                                                 ...               ...
# 1481                                 mjmoreland@aep.com              None
# 1482  Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...              None
# 1483  Shapiro, Richard </O=ENRON/OU=NA/CN=RECIPIENTS...              None
# 1484  Causholli, Monika </O=ENRON/OU=NA/CN=RECIPIENT...              None
# 1485                                  Janette Elbertson  Cynthia Sandherr
#
#      X-bcc                                           X-Folder     X-Origin  \
# 0           \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...     Presto-K
# 1           \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...     Presto-K
# 2           \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...     Presto-K
# 3           \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...     Presto-K
# 4           \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...     Presto-K
# ...    ...                                                ...          ...
# 1481   NaN            \Mike_Carson_Dec2000\Notes Folders\Sent     Carson-M
# 1482   NaN                    \KPRESTO (Non-Privileged)\Inbox     Presto-K
# 1483   NaN  \JSTEFFE (Non-Privileged)\Steffes, James D.\Se...    Steffes-J
# 1484   NaN  \MCAUSHOL (Non-Privileged)\Causholli, Monika\D...  Causholli-M
# 1485   NaN          \Mark_Taylor _Dec_2000\Notes Folders\Sent     Taylor-M
#
#                          X-FileName  \
# 0      kpresto (Non-Privileged).pst
# 1      kpresto (Non-Privileged).pst
# 2      kpresto (Non-Privileged).pst
# 3      kpresto (Non-Privileged).pst
# 4      kpresto (Non-Privileged).pst
# ...                             ...
# 1481                   mcarson2.nsf
# 1482   KPRESTO (Non-Privileged).pst
# 1483   JSTEFFE (Non-Privileged).pst
# 1484  MCAUSHOL (Non-Privileged).pst
# 1485                    mtaylor.nsf
#
#                                                    body  spam  \
# 0     $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $Have...     1
# 1     $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $Your...     1
# 2     $ * $ * $ * $ * $ HOTWEBCASH $ * $ * $ * $ * $...     1
# 3     $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $Find...     1
# 4     $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $Comp...     1
# ...                                                 ...   ...
# 1481  not much ,,,, just got back from chicago (visi...     0
# 1482  This request has been pending your approval fo...     0
# 1483  FYI -----Original Message-----From: Daffin, Ma...     0
# 1484  Monika,Was this already approved by Andrea?  K...     0
# 1485  Here is the language I mentioned in my voice m...     0
#
#                                        body_transformed
# 0     hotwebcash turn receive loan bank poor credit ...
# 1     hotwebcash opinion count ... reward It!Join NP...
# 2     hotwebcash program tailor specific needs!eat F...
# 3     hotwebcash find match ... Click http://r1.adve...
# 4     hotwebcash complete short survey automatically...
# ...                                                 ...
# 1481  get chicago visit come drink kill mule   town ...
# 1482  request pende approval   3 day   click http://...
# 1483  FYI -----original Message-----From Daffin Marg...
# 1484  Monika approve Andrea   Karen-----Original Mes...
# 1485  language mention voice mail   Cynthia Sandherr...
#
# [1486 rows x 20 columns]

# %% [markdown]
# For more reference about the methodology we are going to use take a look into:
# - https://towardsdatascience.com/sentence-transformer-fine-tuning-setfit-outperforms-gpt-3-on-few-shot-text-classification-while-d9a3788f0b4e
# - https://github.com/pmbaumgartner/setfit

# %% [markdown]
# - ### Setfit Classification

# %% [markdown]
# - `1` stands for *spam* mails
# - `0` stands for *non spam* mails

# %%
! pip install git+https://github.com/pmbaumgartner/setfit -q

# %%
from setfit import SetFitClassifier

# %%
complete_df['spam'].value_counts()
# Out:
# 1    1092
# 0     394
# Name: spam, dtype: int64

# %%
train_df, test_df = train_test_split(complete_df, test_size=0.2)

# %%
classifier = SetFitClassifier('paraphrase-MiniLM-L3-v2')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/p8/hcc3hbg92yvd4fclbgllz3380000gn/T/ipykernel_50502/1951735441.py in <module>
# ----> 1 classifier = SetFitClassifier('paraphrase-MiniLM-L3-v2')
#
# ~/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages/setfit/core.py in __init__(self, model, classifier_head, loss, random_state)
#      81         torch.manual_seed(random_state)
#      82         self.random_state = random_state
# ---> 83         self.model = SentenceTransformer(model)
#      84         if classifier_head is None:
#      85             self.classifier_head = LogisticRegression()
#
# ~/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages/sentence_transformers/SentenceTransformer.py in __init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      90                                         library_version=__version__,
#      91                                         ignore_files=['flax_model.msgpack', 'rust_model.ot', 'tf_model.h5'],
# ---> 92                                         use_auth_token=use_auth_token)
#      93
#      94             if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
#
# ~/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages/sentence_transformers/util.py in snapshot_download(repo_id, revision, cache_dir, library_name, library_version, user_agent, ignore_files, use_auth_token)
#     474             os.path.join(storage_folder, relative_filepath)
#     475         )
# --> 476         os.makedirs(nested_dirname, exist_ok=True)
#     477
#     478         cached_download_args = {'url': url,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     211     if head and tail and not path.exists(head):
#     212         try:
# --> 213             makedirs(head, exist_ok=exist_ok)
#     214         except FileExistsError:
#     215             # Defeats race condition when another thread created the path
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     211     if head and tail and not path.exists(head):
#     212         try:
# --> 213             makedirs(head, exist_ok=exist_ok)
#     214         except FileExistsError:
#     215             # Defeats race condition when another thread created the path
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     221             return
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#     225         # Cannot rely on checking for EEXIST, since the operating system
#
# NotADirectoryError: [Errno 20] Not a directory: '/Users/luis.morales/.cache/torch'

# %%
! pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (4.24.0)
# Requirement already satisfied: tqdm in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (1.13.0)
# Requirement already satisfied: torchvision in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (0.14.0)
# Requirement already satisfied: numpy in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: sentencepiece in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from sentence-transformers) (0.11.0)
# Requirement already satisfied: packaging>=20.9 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: importlib-metadata in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (5.0.0)
# Requirement already satisfied: filelock in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: requests in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: click in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from torchvision->sentence-transformers) (9.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/luis.morales/Desktop/MLOpsBootcamp/MLOpsCapstoneProject/mlopsenv/lib/python3.7/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
