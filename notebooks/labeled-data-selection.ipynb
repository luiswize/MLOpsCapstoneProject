# %%
from typing import List, Union
import datetime
import re
import os
from dateutil import parser
from tqdm import tqdm

import pandas as pd
import numpy as np
import email

# %% [markdown]
# ### Utilities

# %%
def parse_email_document(path: str) -> pd.DataFrame:
    """
    Parses email raw file into a dataframe
    """
    
    # TODO: Some files have encoding troubles, as there are asci characteres that raises troubles in the open() block
    # TODO: Fix the encoding characters trouble
    try:
        with open(path) as f:
            contents = f.read()

        msg = email.message_from_string(contents)    

        if 'Cc' in msg:
            _cc = [re.sub('\s+','', msg['Cc']).split(',')] 
        else: 
            _cc = [np.nan]
            
        if 'Bcc' in msg:
            _bcc = [re.sub('\s+','', msg['Cc']).split(',')] 
        else: 
            _bcc = [np.nan]
            
        if 'To' in msg:
            _to = [re.sub('\s+','', msg['To']).split(',')]
        else:
            _to = [np.nan]
        
        attributes = {  
            "Message-ID": [msg["Message-ID"]],
            "Date": [msg["Date"]],
            "From": [re.sub('\s+','', msg['From']).split(',')],
            "To": _to,
            "Subject": [msg["Subject"]],
            "Cc": _cc,
            "Mime-Version": [msg["Mime-Version"]],
            "Content-Type": [msg["Content-Type"]],
            "Content-Transfer-Encoding": [msg["Content-Transfer-Encoding"]],
            "Bcc": _bcc,
            "X-From": [msg["X-From"]],
            "X-To": [msg["X-To"]],
            "X-cc": [msg["X-cc"]],
            "X-bcc": [msg["X-bcc"]],
            "X-Folder": [msg["X-Folder"]],
            "X-Origin": [msg["X-Origin"]],
            "X-FileName": [msg["X-FileName"]]
        }

        if msg.is_multipart():
            for part in email.get_payload():
                body = part.get_payload() 
        else:
            body = msg.get_payload() 
            
        attributes['body'] = body
        df = pd.DataFrame(attributes, columns=attributes.keys())
        return df
    except:
        pass


def get_email_paths(root_directory: str):
    """
    Get list of all files in subfolders of root directory
    """
    files_to_scratch = []
    for path, subdirs, files in os.walk(root_directory):
        
        for name in files:
            files_to_scratch.append(os.path.join(path, name))
            # print(os.path.join(path, name))
    
    return files_to_scratch


def parse_multiple_emails_document(files: List[str]) -> pd.DataFrame:
    """
    Parse list of mails into a dataframe
    """
    columns = ['Message-ID', 'Date', 'From', 'To', 'Subject', 'Cc', 'Mime-Version',
       'Content-Type', 'Content-Transfer-Encoding', 'Bcc', 'X-From', 'X-To',
       'X-cc', 'X-bcc', 'X-Folder', 'X-Origin', 'X-FileName', 'body']
    complete_df = pd.DataFrame(columns=columns)
    
    for path in tqdm(files):
        df = parse_email_document(path)
        complete_df = pd.concat([complete_df, df])
    
    return complete_df.reset_index(drop=True)

# %%
def change_date_type(dates: Union[pd.DataFrame, pd.Series]) -> List:
    """
    Formats string column into datetime object
    """
    column = []
    
    for date in dates:
        column.append(parser.parse(date).strftime("%d-%m-%Y %H:%M:%S"))
    
    series = pd.Series(column)
    return pd.to_datetime(series)


def str_to_list(row):
    """convert a string List into a List"""
    row = str(row).strip("[]").replace("'","")
    return row


def parsed_email_processing(df: pd.DataFrame) -> pd.DataFrame:
    """
    Basic email df formatting and cleaning
    """
    
    df['Date'] = change_date_type(df['Date'])
    
    df['body'] = df['body'].str.replace('\n','').str.replace('\t','')
    
    df['To'] = df['To'].astype('str')\
        .str.replace('b','')\
        .apply(str_to_list)
        
    df['From'] = df['From'].astype('str')\
        .str.replace('b','')\
        .apply(str_to_list)
    
    return df

# %% [markdown]
# ### label selection and cleaning

# %% [markdown]
# #### Spam Data

# %%
spam_paths = get_email_paths('../data/spam/')
spam_df = parse_multiple_emails_document(spam_paths)
# Out:
# 100%|██████████| 1093/1093 [00:04<00:00, 233.22it/s]

# %%
spam_df['spam'] = 1
spam_df.head()
# Out:
#                                       Message-ID  \
# 0   <8307461.1075860887277.JavaMail.evans@thyme>
# 1  <31088330.1075860887438.JavaMail.evans@thyme>
# 2   <8829953.1075860887541.JavaMail.evans@thyme>
# 3  <25503194.1075860887462.JavaMail.evans@thyme>
# 4   <3520246.1075860887301.JavaMail.evans@thyme>
#
#                                    Date                              From  \
# 0  Tue, 3 Feb 2004 18:14:47 -0800 (PST)  [hotwebcash@lists.adversend.com]
# 1  Tue, 3 Feb 2004 18:14:47 -0800 (PST)  [hotwebcash@lists.adversend.com]
# 2  Tue, 3 Feb 2004 18:14:47 -0800 (PST)  [hotwebcash@lists.adversend.com]
# 3  Tue, 3 Feb 2004 18:14:47 -0800 (PST)  [hotwebcash@lists.adversend.com]
# 4  Tue, 3 Feb 2004 18:14:47 -0800 (PST)  [hotwebcash@lists.adversend.com]
#
#                       To                                   Subject   Cc  \
# 0  [m..presto@enron.com]            Free Grants For Those In Need!  NaN
# 1  [m..presto@enron.com]          Your Opinion Counts...Win $1000!  NaN
# 2  [m..presto@enron.com]                   LOSE POUNDS GUARANTEED!  NaN
# 3  [m..presto@enron.com]             Someone is searching for YOU!  NaN
# 4  [m..presto@enron.com]  Take a Survey, Win a FREE New Computer!!  NaN
#
#   Mime-Version                  Content-Type Content-Transfer-Encoding  Bcc  \
# 0          1.0  text/plain; charset=us-ascii                      7bit  NaN
# 1          1.0  text/plain; charset=us-ascii                      7bit  NaN
# 2          1.0  text/plain; charset=us-ascii                      7bit  NaN
# 3          1.0  text/plain; charset=us-ascii                      7bit  NaN
# 4          1.0  text/plain; charset=us-ascii                      7bit  NaN
#
#                                               X-From  \
# 0  HotWebCash Newsletter <hotwebcash@lists.advers...
# 1  HotWebCash Newsletter <hotwebcash@lists.advers...
# 2  HotWebCash Newsletter <hotwebcash@lists.advers...
# 3  HotWebCash Newsletter <hotwebcash@lists.advers...
# 4  HotWebCash Newsletter <hotwebcash@lists.advers...
#
#                                                 X-To X-cc X-bcc  \
# 0  Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 1  Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 2  Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 3  Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 4  Presto, Kevin M. </O=ENRON/OU=NA/CN=RECIPIENTS...
#
#                                             X-Folder  X-Origin  \
# 0  \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...  Presto-K
# 1  \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...  Presto-K
# 2  \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...  Presto-K
# 3  \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...  Presto-K
# 4  \Kevin_Presto_Mar2002_1\Presto, Kevin M.\Junk ...  Presto-K
#
#                      X-FileName  \
# 0  kpresto (Non-Privileged).pst
# 1  kpresto (Non-Privileged).pst
# 2  kpresto (Non-Privileged).pst
# 3  kpresto (Non-Privileged).pst
# 4  kpresto (Non-Privileged).pst
#
#                                                 body  spam
# 0  $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $\n\n...     1
# 1  $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $\n\n...     1
# 2  $ * $ * $ * $ * $ HOTWEBCASH $ * $ * $ * $ * $...     1
# 3  $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $\n\n...     1
# 4  $ * $ * $ * $ * HOTWEBCASH * $ * $ * $ * $\n\n...     1

# %%
spam_df.to_parquet('../data/labeled_data/spam.parquet.gzip', compression='gzip', engine='fastparquet')

# %% [markdown]
# #### Not Spam Data

# %%
complete_df = pd.read_parquet('../data/preprocessing_output/cleaned_mails_v0.parquet.gzip')

# %%
complete_df
# Out:
#                                            Message-ID                Date  \
# 0       <17334447.1075857585446.JavaMail.evans@thyme> 2000-11-16 09:30:00
# 1       <19171686.1075857585034.JavaMail.evans@thyme> 2000-08-12 05:05:00
# 2       <29887033.1075857630725.JavaMail.evans@thyme> 2001-05-15 09:43:00
# 3       <29084893.1075849630138.JavaMail.evans@thyme> 2000-11-27 01:49:00
# 4       <30248874.1075857584813.JavaMail.evans@thyme> 2000-12-12 09:33:00
# ...                                               ...                 ...
# 517306  <18618854.1075840028791.JavaMail.evans@thyme> 2001-11-10 09:39:47
# 517307  <14350892.1075840028690.JavaMail.evans@thyme> 2001-10-17 16:11:39
# 517308  <21704474.1075840029683.JavaMail.evans@thyme> 2001-06-04 01:42:00
# 517309   <9367927.1075840029633.JavaMail.evans@thyme> 2001-09-04 23:11:00
# 517310   <9368661.1075840029659.JavaMail.evans@thyme> 2001-09-04 21:55:00
#
#                                  From  \
# 0                 ["msagel@home.com"]
# 1          ["slafontaine@gloalp.com"]
# 2         ["iceoperations@intcx.com"]
# 3       ["jeff.youngflesh@enron.com"]
# 4        ["caroline.aramo@enron.com"]
# ...                               ...
# 517306  ["jodi.droll@xcelenergy.com"]
# 517307       ["mark.hackney@aps.com"]
# 517308   ["paul.rice@pacificorp.com"]
# 517309            ["gjcarter@pa.gov"]
# 517310     ["khara@avistaenergy.com"]
#
#                                                        To  \
# 0                                   ["jarnold@enron.com"]
# 1                               ["john.arnold@enron.com"]
# 2       ["icehelpdesk@intcx.com", "internalmarketing@i...
# 3       ["anthony.gilmore@enron.com", "colleen.koenig@...
# 4                               ["mike.grigsy@enron.com"]
# ...                                                   ...
# 517306                                  ["isas@wscc.com"]
# 517307                                  ["isas@wscc.com"]
# 517308                                  ["isas@wscc.com"]
# 517309  ["\hara@enron.com", "khara@avistaenergy.com", ...
# 517310  ["cara.semperger@enron.com", "demetrios.fotiou...
#
#                                                   Subject  \
# 0                                                  Status
# 1                                      re:summer inverses
# 2                           The WTI Bullet swap contracts
# 3       Invitation: EBS/GSS Meeting w/Bristol Babcock ...
# 4                                            Harvard Mgmt
# ...                                                   ...
# 517306                       RE: Scheduling Time constant
# 517307      FW: Standards Announcement - October 17, 2001
# 517308                                          Late tags
# 517309                 RE: BCHA Automatic Denial/Approval
# 517310                 FW: BCHA Automatic Denial/Approval
#
#                                   Cc Mime-Version  \
# 0                               None          1.0
# 1                               None          1.0
# 2                               None          1.0
# 3                               None          1.0
# 4       b'["john.arnold@enron.com"]'          1.0
# ...                              ...          ...
# 517306                          None          1.0
# 517307                          None          1.0
# 517308                          None          1.0
# 517309                          None          1.0
# 517310                          None          1.0
#
#                               Content-Type Content-Transfer-Encoding  \
# 0       text/plain; charset=ANSI_X3.4-1968                      7bit
# 1             text/plain; charset=us-ascii                      7bit
# 2             text/plain; charset=us-ascii                      7bit
# 3             text/plain; charset=us-ascii                      7bit
# 4             text/plain; charset=us-ascii                      7bit
# ...                                    ...                       ...
# 517306        text/plain; charset=us-ascii                      7bit
# 517307        text/plain; charset=us-ascii                      7bit
# 517308        text/plain; charset=us-ascii                      7bit
# 517309        text/plain; charset=us-ascii                      7bit
# 517310        text/plain; charset=us-ascii                      7bit
#
#                                  Bcc  \
# 0                               None
# 1                               None
# 2                               None
# 3                               None
# 4       b'["john.arnold@enron.com"]'
# ...                              ...
# 517306                          None
# 517307                          None
# 517308                          None
# 517309                          None
# 517310                          None
#
#                                                   X-From  \
# 0                         "Mark Sagel" <msagel@home.com>
# 1                                slafontaine@globalp.com
# 2               ICE Operations <ICEOperations@intcx.com>
# 3                                        Jeff Youngflesh
# 4                                        Caroline Abramo
# ...                                                  ...
# 517306           Droll, Jodi <Jodi.Droll@XCELENERGY.COM>
# 517307    Hackney, Mark W(Z39911) <Mark.Hackney@aps.com>
# 517308            Rice, Paul  <Paul.Rice@Pacificorp.com>
# 517309  Carter, Gloria J - TMS-DITT1  <gjcarter@bpa.gov>
# 517310             Hara, Kathy  <KHara@avistaenergy.com>
#
#                                                      X-To         X-cc X-bcc  \
# 0                       "John Arnold" <jarnold@enron.com>
# 1                                   John.Arnold@enron.com
# 2       **ICEHELPDESK <**ICEHELPDESK@intcx.com>, **Int...
# 3       Anthony Gilmore, Colleen Koenig, Jennifer Stew...
# 4                                            Mike Grigsby  John Arnold
# ...                                                   ...          ...   ...
# 517306  Interchange Scheduling & Accounting Subcommitt...
# 517307  Interchange Scheduling & Accounting Subcommitt...
# 517308  Interchange Scheduling & Accounting Subcommitt...
# 517309  'Hara, Kathy'  <KHara@avistaenergy.com>, Cara ...
# 517310  Cara Semperger (E-mail)  <cara.semperger@enron...
#
#                                               X-Folder    X-Origin  \
# 0       \John_Arnold_Dec2000\Notes Folders\Notes inbox    Arnold-J
# 1       \John_Arnold_Dec2000\Notes Folders\Notes inbox    Arnold-J
# 2       \John_Arnold_Jun2001\Notes Folders\Notes inbox    Arnold-J
# 3       \John_Arnold_Nov2001\Notes Folders\Notes inbox    ARNOLD-J
# 4       \John_Arnold_Dec2000\Notes Folders\Notes inbox    Arnold-J
# ...                                                ...         ...
# 517306   \ExMerge - Scholtes, Diana\STF\Current issues  SCHOLTES-D
# 517307   \ExMerge - Scholtes, Diana\STF\Current issues  SCHOLTES-D
# 517308            \ExMerge - Scholtes, Diana\STF\E-TAG  SCHOLTES-D
# 517309            \ExMerge - Scholtes, Diana\STF\E-TAG  SCHOLTES-D
# 517310            \ExMerge - Scholtes, Diana\STF\E-TAG  SCHOLTES-D
#
#          X-FileName                                               body
# 0       Jarnold.nsf  John:?I'm not really sure what happened betwee...
# 1       Jarnold.nsf  i suck-hope youve made more money in natgas la...
# 2       Jarnold.nsf   Hi,  Following the e-mail you have received y...
# 3       jarnold.nsf  Conference Room TBD.  This meeting will be to ...
# 4       Jarnold.nsf  Mike- I have their trader coming into the offi...
# ...             ...                                                ...
# 517306               I (PSCO TP & CA) agree with Don.  I thought we...
# 517307               FYI!!-----Original Message-----From: Barbara B...
# 517308               Nothing is easy is it??  At the risk of the cr...
# 517309               I think you are right on! In addition, I would...
# 517310               >  -----Original Message-----> From: Hara, Kat...
#
# [517311 rows x 18 columns]

# %%
bool_mask = complete_df['From'].str.contains("enron.com")
not_spam_df = complete_df[bool_mask].sample(400)

# %%
# not_spam_df.to_csv('../data/no_spam/non_spam_contenients.csv')

# %% [markdown]
# ## Labeling Data

# %% [markdown]
# The csv was read again because the datset was examined one by one to confirm the mails were not spam

# %%
nonspam_df = pd.read_csv('../data/no_spam/non_spam_contenients.csv', index_col=0).reset_index(drop=True)

# %%
nonspam_df['spam'] = 0
nonspam_df.head()
# Out:
#                                       Message-ID           Date  \
# 0   <8986238.1075840559090.JavaMail.evans@thyme>  25/01/02 9:22
# 1  <29456384.1075857390009.JavaMail.evans@thyme>  05/08/01 5:31
# 2  <11995525.1075851754784.JavaMail.evans@thyme>  15/12/00 7:31
# 3   <5560011.1075843043584.JavaMail.evans@thyme>  22/11/00 0:21
# 4  <13364954.1075842809447.JavaMail.evans@thyme>  14/05/01 3:03
#
#                          From  \
# 0      ["c..giron@enron.com"]
# 1  ["outlook.team@enron.com"]
# 2  ["samantha.oyd@enron.com"]
# 3    ["susan.mara@enron.com"]
# 4      ["kim.ward@enron.com"]
#
#                                                   To  \
# 0  ["elena.chilkina@enron.com", "m..love@enron.com"]
# 1  ["angela.mendez@enron.com", "angeline.stewart@...
# 2  ["o.owen@enron.com", "laurel.adams@enron.com",...
# 3                        ["james.steffes@enron.com"]
# 4  ["arry.tycholiz@enron.com", "gerald.nemec@enro...
#
#                                              Subject  \
# 0                         NG-PRICE_FinancialOnly.xls
# 1        1-URGENT - Outlook Email Notification (new)
# 2                           MIECO INC. -  CORRECTION
# 3  Re: Enron's Response Today - Key Point to Focu...
# 4                                          Palo Alto
#
#                                                   Cc  Mime-Version  \
# 0  b'["ed.mcmichael@enron.com", "c..gossett@enron...             1
# 1                                                NaN             1
# 2                                                NaN             1
# 3  b'["alan.comnes@enron.com", "bernadette.hawkin...             1
# 4                                                NaN             1
#
#                          Content-Type Content-Transfer-Encoding  \
# 0        text/plain; charset=us-ascii                      7bit
# 1  text/plain; charset=ANSI_X3.4-1968          quoted-printable
# 2        text/plain; charset=us-ascii                      7bit
# 3        text/plain; charset=us-ascii                      7bit
# 4        text/plain; charset=us-ascii                      7bit
#
#                                                  Bcc  \
# 0  b'["ed.mcmichael@enron.com", "c..gossett@enron...
# 1                                                NaN
# 2                                                NaN
# 3  b'["alan.comnes@enron.com", "bernadette.hawkin...
# 4                                                NaN
#
#                                               X-From  \
# 0  Giron, Darron C. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 1                             Outlook Migration Team
# 2                                      Samantha Boyd
# 3                                       Susan J Mara
# 4                                           Kim Ward
#
#                                                 X-To  \
# 0  Chilkina, Elena </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 1  Angela Mendez, Angeline Stewart, Bobbie LaChap...
# 2  Bob Bowen, Laurel Adams, Andrea R Guillen, Lar...
# 3                                    James D Steffes
# 4                       Barry Tycholiz, Gerald Nemec
#
#                                                 X-cc  X-bcc  \
# 0  McMichael Jr., Ed </O=ENRON/OU=NA/CN=RECIPIENT...    NaN
# 1                                                NaN    NaN
# 2                                                NaN    NaN
# 3  Alan Comnes, bernadette Hawkins, Christopher F...    NaN
# 4                                                NaN    NaN
#
#                                             X-Folder      X-Origin  \
# 0             \ExMerge - Giron, Darron C.\Sent Items       GIRON-D
# 1  \Errol_McLaughlin_Jun2001\Notes Folders\All do...  McLaughlin-E
# 2        \Jason_Williams_Nov2001\Notes Folders\Legal    WILLIAMS-J
# 3  \Jeff_Dasovich_Dec2000\Notes Folders\All docum...    DASOVICH-J
# 4  \Gerald_Nemec_Dec2000_June2001_2\Notes Folders...       NEMEC-G
#
#                  X-FileName  \
# 0  darron giron 6-26-02.PST
# 1               emclaug.nsf
# 2              jwilli10.nsf
# 3              jdasovic.nsf
# 4                gnemec.nsf
#
#                                                 body  spam
# 0  The file was too big to email.  It contains al...     0
# 1  OUTLOOK EMAIL NOTIFICATIONYour Date of Migrati...     0
# 2  We have received an executed Master Agreement:...     0
# 3  I know that WPTF is supporting Hebert's approa...     0
# 4  Do we need to meet this morning regarding our ...     0

# %%
nonspam_df.to_parquet('../data/labeled_data/nonspam.parquet.gzip', compression='gzip', engine='fastparquet')
